# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanyarat281-6/dataviz2025/blob/main/Visualize_Data_Comparison_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
# from datetime import datetime as dt
# from datetime import time

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Python&datavizz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
data = pd.read_csv(path)
# data = data.iloc[:,1:]
data.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# 0                        Arrest                              False
# 1  A no further action disposal                                NaN
# 2  A no further action disposal                                NaN
# 3  A no further action disposal                                NaN
# 4  A no further action disposal                                NaN
#
#    Removal of more than just outer clothing
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False

# %% [markdown]
# # Q12
# สร้างตารางที่แสดงความถี่ของจำนวน case ที่จับโดยตำรวจเชื้อชาติต่างๆ

# %%
compared_police_eth= data.groupby('Officer-defined ethnicity')['Type'].count()
compared_police_eth
# Out:
# Officer-defined ethnicity
# Asian     81
# Black     64
# Other      9
# White    199
# Name: Type, dtype: int64

# %% [markdown]
# ## Bar chart (กราฟแท่ง) (กราฟผลไม้)

# %%
# plt.bar(compared_police_eth['Officer-defined ethnicity'], compared_police_eth['Type']); <- วิวรันไม่ได้

# %%
plt.bar(compared_police_eth.index, compared_police_eth.values);

# %%
import matplotlib.pyplot as plt
plt.bar(compared_police_eth.index, compared_police_eth.values, color=['#ffd8b1', '#000000', '#e6194B', '#a9a9a9']) # Using a set of distinct colors
plt.xlabel('Officer-defined ethnicity')
plt.ylabel(' cases')
plt.title('Number of cases by officer-defined ethnicity')
# Out:
# Text(0.5, 1.0, 'Number of cases by officer-defined ethnicity')

# %% [markdown]
# # stacked barchart

# %%
data1= '/content/drive/MyDrive/Python&datavizz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
data2= '/content/drive/MyDrive/Python&datavizz2025/data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
data3= '/content/drive/MyDrive/Python&datavizz2025/data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
data4= '/content/drive/MyDrive/Python&datavizz2025/data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
compared_police_eth1 = pd.read_csv(data1).groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compared_police_eth2 = pd.read_csv(data2).groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compared_police_eth3 = pd.read_csv(data3).groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compared_police_eth4 = pd.read_csv(data4).groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')

# %%
plt.bar(compared_police_eth1['Officer-defined ethnicity'], compared_police_eth1['Type']
        , color=[[107/255,108/255,109/255,0.4], [107/255,77/255,0,0.4], [249/255,249/255,0,0.4], [250/255,117/255,117/255,0.4]]
        ,label='Jan')
plt.bar(compared_police_eth2['Officer-defined ethnicity'], compared_police_eth2['Type']
        , bottom = compared_police_eth1['Type']
        , color=[[107/255,108/255,109/255,0.5], [107/255,77/255,0,0.5], [249/255,249/255,0,0.5], [250/255,117/255,117/255,0.5]]
        , label='Feb')
plt.bar(compared_police_eth3['Officer-defined ethnicity'], compared_police_eth3['Type']
        , bottom = compared_police_eth1['Type'] + compared_police_eth2['Type']
        , color=[[107/255,108/255,109/255,0.6], [107/255,77/255,0,0.6], [249/255,249/255,0,0.6], [250/255,117/255,117/255,0.6]]
        , label='Mar')
plt.bar(compared_police_eth4['Officer-defined ethnicity'], compared_police_eth4['Type']
        , bottom = compared_police_eth1['Type'] + compared_police_eth2['Type']+ compared_police_eth3['Type']
        , color=[[107/255,108/255,109/255,0.7], [107/255,77/255,0,0.7], [249/255,249/255,0,0.7], [250/255,117/255,117/255,0.7]]
        , label='Apr')
plt.xlabel('Ethnicity')
plt.ylabel('Cases')
plt.legend()
plt.title('Number of Cases open by polices with different ethnicities over Jan-Apr 2025');

# %%
# Combine the data from each month into a single DataFrame
combined_ethnicity_counts = pd.concat([compared_police_eth1, compared_police_eth2, compared_police_eth3, compared_police_eth4], axis=1)

# %%
asian_index = compared_police_eth1.index[compared_police_eth1.index =='Asian'][0]
black_index = compared_police_eth1.index[compared_police_eth1.index =='Black'][0]
white_index = compared_police_eth1.index[compared_police_eth1.index =='White'][0]
other_index = compared_police_eth1.index[compared_police_eth1.index =='Other'][0]

#
asian_rowm = compared_police_eth1.loc[asian_index].copy()
black_rowm = compared_police_eth1.loc[black_index].copy()
white_rowm = compared_police_eth1.loc[white_index].copy()
other_rowm =  compared_police_eth1.loc[other_index].copy() # Corrected to use other_index


compared_police_eth1.loc[asian_index] = black_rowm
compared_police_eth1.loc[black_index] = white_rowm
compared_police_eth1.loc[white_index] = other_rowm
compared_police_eth1.loc[other_index] = asian_rowm

display(compared_police_eth1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1882918851.py in <cell line: 0>()
# ----> 1 asian_index = compared_police_eth1.index[compared_police_eth1.index =='Asian'][0]
#       2 black_index = compared_police_eth1.index[compared_police_eth1.index =='Black'][0]
#       3 white_index = compared_police_eth1.index[compared_police_eth1.index =='White'][0]
#       4 other_index = compared_police_eth1.index[compared_police_eth1.index =='Other'][0]
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5387             # GH#44051 exclude bool, which would return a 2d ndarray
#    5388             key = com.cast_scalar_indexer(key)
# -> 5389             return getitem(key)
#    5390
#    5391         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()

# %% [markdown]
# ## Plot stacked barchart ด้วย matplotlib

# %%
region_brand_sales = data.groupby(['Region', 'Brand'])['Sales'].sum().unstack()
region_brand_sales
# Out:
# Brand          BrandA  BrandB  BrandC  BrandD
# Region
# Africa         132019  140187  132273  137077
# Asia           136205  124678  139677  119048
# Europe         135638  135069  131700  145661
# North America  124810  153135  140802  126816
# South America  144169  138543  115774  130760

# %%
region_brand_sales['BrandA'].values
# Out:
# array([132019, 136205, 135638, 124810, 144169])

# %%
region_brand_sales.index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'South America'], dtype='object', name='Region')

# %% [markdown]
# ## plot ส่วนแรก

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 2

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width, bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 3

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width,
       bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
ax.bar(region_brand_sales.index, region_brand_sales['BrandC'].values, width,
       bottom=region_brand_sales['BrandA'].values + region_brand_sales['BrandB'].values, label='BrandC',color = '#FF5733')


ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# # Grouped bar chart (เปรียบเทียบในกลุ่ม)

# %%
import numpy as np

# %%
x = np.arange(len(compared_police_eth1))  # the label locations
width = 0.35  # the width of the bars

# โค้ดหลัก
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, compared_police_eth1['Type'], width, label='Jan',color = '#fc9700')
rects2 = ax.bar(x + width/2, compared_police_eth2['Type'], width, label='Feb', color = '#19038a')

#โค้ดที่ทำให้คนอื่นรู้
ax.set_ylabel('Number of cases')
ax.set_title('Compare number of cases between different months')
ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend()

# %% [markdown]
# # Quiz 13
# plot grouped barchart เปรียบเทียบจำนวน cases 3 เดือน ของแต่ละ เชื้อชาติ

# %%
x = np.arange(len(compared_police_eth1))  # the label locations
width = 0.25  # the width of the bars

# โค้ดหลัก
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, compared_police_eth1['Type'], width, label='Jan',color = '#fc9700')
rects2 = ax.bar(x + width/2 , compared_police_eth2['Type'], width, label='Feb', color = '#19038a')
rects3 = ax.bar(x + width/0.7, compared_police_eth3['Type'], width, label='Mar', color = '#FF5733')

#โค้ดที่ทำให้คนอื่นรู้
ax.set_ylabel('Number of cases')
ax.set_title('Compare number of cases between different months')
ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend()

# %%
compared_police_eth
# Out:
# Officer-defined ethnicity
# Asian     81
# Black     64
# Other      9
# White    199
# Name: Type, dtype: int64

# %%
compared_police_eth2
# Out:
#   Officer-defined ethnicity  Type
# 2                     Other     3
# 1                     Black    50
# 0                     Asian    63
# 3                     White   151

# %%
compared_police_eth1
# Out:
#   Officer-defined ethnicity  Type
# 2                     Other     9
# 1                     Black    64
# 0                     Asian    81
# 3                     White   199

# %% [markdown]
# #การแสดงผล ภาษาไทย

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
x = np.arange(len(compared_police_eth1))  # the label locations
width = 0.35  # the width of the bars

# โค้ดหลัก
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, compared_police_eth1['Type'], width, label='มกราคม',color = '#fc9700')
rects2 = ax.bar(x + width/2, compared_police_eth2['Type'], width, label='กุมภาพันธ์', color = '#19038a')

#โค้ดที่ทำให้คนอื่นรู้
ax.set_ylabel('Number of cases')
ax.set_title('Compare number of cases between different months')
ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend()

# %% [markdown]
# # Tree map

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4

# %%
import squarify
# Calculate the count of cases for each 'Object of search'
data_jan = pd.read_csv(data1)
object_counts = data_jan['Object of search'].value_counts()
# Create the treemap
plt.figure(figsize=(10, 6))
squarify.plot(sizes=object_counts.values, label=object_counts.index, alpha=.8)
plt.title('Number of Cases by Object of Search')
plt.axis('off')
plt.show();

# %%
import squarify
import matplotlib.pyplot as plt

# Calculate the count of cases for each 'Object of search'
object_counts = data_jan['Object of search'].value_counts()

# Define a list of colors
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#B00C0C'] # Example colors

# Create the treemap with custom colors
plt.figure(figsize=(10, 6))
squarify.plot(sizes=object_counts.values, label=object_counts.index, alpha=.8, color=colors)
plt.title('Number of Cases by Object of Search (with custom colors)')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Radar Chart

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.iloc[:,1:].mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 4),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid' , color = '#ea3033') #เส้นกราฟ
ax.fill(angles, values, 'lightpink', alpha=0.5) #พื้นที่

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 4),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# โหลดไฟล์สองเมือง
df_cheshire = pd.read_csv("/content/drive/MyDrive/Python&datavizz2025/data/2025-01/2025-01-cheshire-street.csv")
df_cambridge = pd.read_csv("/content/drive/MyDrive/Python&datavizz2025/data/2025-01/2025-01-cumbria-street.csv")

# นับจำนวนอาชญากรรมแต่ละประเภทในแต่ละเมือง
crime_cheshire = df_cheshire['Crime type'].value_counts(normalize=True) * 100
crime_cambridge = df_cambridge['Crime type'].value_counts(normalize=True) * 100

# รวม crime type ที่มีในทั้งสองเมือง
crime_total = (crime_cheshire.add(crime_cambridge, fill_value=0)).sort_values(ascending=False)

# เลือก top 5 crime type
top5_crimes = crime_total.head(5).index

# เตรียมข้อมูลสำหรับ radar chart (%)
data_cheshire = [crime_cheshire.get(c, 0) for c in top5_crimes]
data_cambridge = [crime_cambridge.get(c, 0) for c in top5_crimes]

# ปิดวงเชื่อมต่อ
data_cheshire += data_cheshire[:1]
data_cambridge += data_cambridge[:1]

# มุมสำหรับ plot
angles = np.linspace(0, 2*np.pi, len(top5_crimes), endpoint=False).tolist()
angles += angles[:1]

# --- Radar Chart ---
fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))
ax.plot(angles, data_cheshire, linewidth=2, label="Cheshire")
ax.fill(angles, data_cheshire, alpha=0.25)

ax.plot(angles, data_cambridge, linewidth=2, label="Cambridgeshire")
ax.fill(angles, data_cambridge, alpha=0.25)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(top5_crimes, fontsize=10)
ax.set_title("Top 5 Crime Types (% Comparison)", fontsize=14)
ax.legend(loc="upper right", bbox_to_anchor=(1.3,1.1))
plt.show()

# --- ตารางสรุปเป็น % ---
summary_df = pd.DataFrame({
    "Crime Type": top5_crimes,
    "Cheshire (%)": [crime_cheshire.get(c, 0) for c in top5_crimes],
    "Cambridgeshire (%)": [crime_cambridge.get(c, 0) for c in top5_crimes]
})

print("Top 5 Crime Types (% Comparison)")
print(summary_df.round(2))
# Out:
# Top 5 Crime Types (% Comparison)
#                      Crime Type  Cheshire (%)  Cambridgeshire (%)
# 0  Violence and sexual offences         49.41               48.20
# 1                  Public order          9.72                8.74
# 2     Criminal damage and arson          7.00                8.77
# 3         Anti-social behaviour          7.19                6.32
# 4                   Shoplifting          6.60                5.08
