# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanyarat281-6/dataviz2025/blob/main/HW_4_%E0%B8%81%E0%B8%A5%E0%B8%B8%E0%B9%88%E0%B8%A1_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HW 4  ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##2025-01

# %%
data_all_01 = '/content/drive/MyDrive/Python&datavizz2025/data/2025-01'

# %%
csv_files_01 = [f for f in os.listdir(data_all_01) if f.endswith('.csv')]

# %%
select_files_01 = [file for file in csv_files_01 if 'stop-and-search' in file]
len(select_files_01)

 # มี 38 เมือง
# Out:
# 38

# %% [markdown]
# ## 2025-02

# %%
data_all_02 = '/content/drive/MyDrive/Python&datavizz2025/data/2025-02'

# %%
csv_files_02 = [f for f in os.listdir(data_all_02) if f.endswith('.csv')]

# %%
select_files_02 = [file for file in csv_files_02 if 'stop-and-search' in file]
len(select_files_02)

 # มี 38 เมือง
# Out:
# 38

# %% [markdown]
# ##  2025-03

# %%
data_all_03 = '/content/drive/MyDrive/Python&datavizz2025/data/2025-03'

# %%
csv_files_03 = [f for f in os.listdir(data_all_03) if f.endswith('.csv')]

# %%
select_files_03 = [file for file in csv_files_03 if 'stop-and-search' in file]
len(select_files_03)

 # มี 37 เมือง
# Out:
# 37

# %% [markdown]
# # *2025-04*

# %%
data_all_04 = '/content/drive/MyDrive/Python&datavizz2025/data/2025-04'

# %%
csv_files_04 = [f for f in os.listdir(data_all_04) if f.endswith('.csv')]

# %%
select_files_04 = [file for file in csv_files_04 if 'stop-and-search' in file]
len(select_files_04)

 # มี 37 เมือง
# Out:
# 37

# %% [markdown]
# # 2025-05

# %%
data_all_05 = '/content/drive/MyDrive/Python&datavizz2025/data/2025-05'

# %%
csv_files_05 = [f for f in os.listdir(data_all_05) if f.endswith('.csv')]

# %%
select_files_05 = [file for file in csv_files_05 if 'stop-and-search' in file]
len(select_files_05)

 # มี 36 เมือง
# Out:
# 36

# %% [markdown]
# # ดูว่าเดือนไหนมีเมืองอะไรบ้างและเดือนในไม่มีเมืองอะไร

# %%
# แยกชื่อเมืองจากชื่อไฟล์สำหรับทั้งห้าเดือน
cities_01 = set([file.split('-stop-and-search')[0].split('-', 2)[-1] for file in select_files_01])
cities_02 = set([file.split('-stop-and-search')[0].split('-', 2)[-1] for file in select_files_02])
cities_03 = set([file.split('-stop-and-search')[0].split('-', 2)[-1] for file in select_files_03])
cities_04 = set([file.split('-stop-and-search')[0].split('-', 2)[-1] for file in select_files_04])
cities_05 = set([file.split('-stop-and-search')[0].split('-', 2)[-1] for file in select_files_05])

# ค้นหาเมืองที่มีอยู่ในทั้งห้าเดือน (ส่วนที่ซ้ำกัน)
cities_in_all_months = cities_01.intersection(cities_02, cities_03, cities_04, cities_05)

# รวมเมืองทั้งหมดจากทุกเดือน (ยูเนียน)
all_cities = cities_01.union(cities_02, cities_03, cities_04, cities_05)

# สร้าง DataFrame ที่มีเมืองที่ไม่ซ้ำกันทั้งหมด
df_cities = pd.DataFrame({'City': list(all_cities)})

# เพิ่มคอลัมน์สำหรับแต่ละเดือนเพื่อระบุการมีอยู่ของเมือง
df_cities['2025-01'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_01 else 'No')
df_cities['2025-02'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_02 else 'No')
df_cities['2025-03'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_03 else 'No')
df_cities['2025-04'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_04 else 'No')
df_cities['2025-05'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_05 else 'No')

# เพิ่มคอลัมน์เพื่อระบุว่าเมืองนั้นมีอยู่ในทั้งห้าเดือนหรือไม่
df_cities['Present in all 5 months'] = df_cities['City'].apply(lambda x: 'Yes' if x in cities_in_all_months else 'No')

# ฟังก์ชันสำหรับไฮไลท์เฉพาะค่า 'No' เป็นสีแดง
def highlight_no_in_red(cell_value):
    if cell_value == 'No':
        return 'background-color: red'
    return '' # ไม่ไฮไลท์ค่าอื่น

# ใช้ไฮไลท์เฉพาะค่า 'No' ในทุกคอลัมน์
styled_df = df_cities.style.applymap(highlight_no_in_red)


print("การมีอยู่ของเมืองในแต่ละเดือน:")
display(styled_df)
# Out:
# การมีอยู่ของเมืองในแต่ละเดือน:
# /tmp/ipython-input-3462584695.py:34: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_cities.style.applymap(highlight_no_in_red)
# <style type="text/css">
# #T_b4c55_row1_col3, #T_b4c55_row1_col4, #T_b4c55_row1_col6, #T_b4c55_row6_col5, #T_b4c55_row6_col6, #T_b4c55_row8_col5, #T_b4c55_row8_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_b4c55" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4c55_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b4c55_level0_col1" class="col_heading level0 col1" >2025-01</th>
#       <th id="T_b4c55_level0_col2" class="col_heading level0 col2" >2025-02</th>
#       <th id="T_b4c55_level0_col3" class="col_heading level0 col3" >2025-03</th>
#       <th id="T_b4c55_level0_col4" class="col_heading level0 col4" >2025-04</th>
#       <th id="T_b4c55_level0_col5" class="col_heading level0 col5" >2025-05</th>
#       <th id="T_b4c55_level0_col6" class="col_heading level0 col6" >Present in all 5 months</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4c55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4c55_row0_col0" class="data row0 col0" >warwickshire</td>
#       <td id="T_b4c55_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_b4c55_row0_col2" class="data row0 col2" >Yes</td>
#       <td id="T_b4c55_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_b4c55_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_b4c55_row0_col5" class="data row0 col5" >Yes</td>
#       <td id="T_b4c55_row0_col6" class="data row0 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4c55_row1_col0" class="data row1 col0" >merseyside</td>
#       <td id="T_b4c55_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_b4c55_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_b4c55_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_b4c55_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_b4c55_row1_col5" class="data row1 col5" >Yes</td>
#       <td id="T_b4c55_row1_col6" class="data row1 col6" >No</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4c55_row2_col0" class="data row2 col0" >nottinghamshire</td>
#       <td id="T_b4c55_row2_col1" class="data row2 col1" >Yes</td>
#       <td id="T_b4c55_row2_col2" class="data row2 col2" >Yes</td>
#       <td id="T_b4c55_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_b4c55_row2_col4" class="data row2 col4" >Yes</td>
#       <td id="T_b4c55_row2_col5" class="data row2 col5" >Yes</td>
#       <td id="T_b4c55_row2_col6" class="data row2 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4c55_row3_col0" class="data row3 col0" >northamptonshire</td>
#       <td id="T_b4c55_row3_col1" class="data row3 col1" >Yes</td>
#       <td id="T_b4c55_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_b4c55_row3_col3" class="data row3 col3" >Yes</td>
#       <td id="T_b4c55_row3_col4" class="data row3 col4" >Yes</td>
#       <td id="T_b4c55_row3_col5" class="data row3 col5" >Yes</td>
#       <td id="T_b4c55_row3_col6" class="data row3 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4c55_row4_col0" class="data row4 col0" >dyfed-powys</td>
#       <td id="T_b4c55_row4_col1" class="data row4 col1" >Yes</td>
#       <td id="T_b4c55_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_b4c55_row4_col3" class="data row4 col3" >Yes</td>
#       <td id="T_b4c55_row4_col4" class="data row4 col4" >Yes</td>
#       <td id="T_b4c55_row4_col5" class="data row4 col5" >Yes</td>
#       <td id="T_b4c55_row4_col6" class="data row4 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4c55_row5_col0" class="data row5 col0" >south-yorkshire</td>
#       <td id="T_b4c55_row5_col1" class="data row5 col1" >Yes</td>
#       <td id="T_b4c55_row5_col2" class="data row5 col2" >Yes</td>
#       <td id="T_b4c55_row5_col3" class="data row5 col3" >Yes</td>
#       <td id="T_b4c55_row5_col4" class="data row5 col4" >Yes</td>
#       <td id="T_b4c55_row5_col5" class="data row5 col5" >Yes</td>
#       <td id="T_b4c55_row5_col6" class="data row5 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b4c55_row6_col0" class="data row6 col0" >derbyshire</td>
#       <td id="T_b4c55_row6_col1" class="data row6 col1" >Yes</td>
#       <td id="T_b4c55_row6_col2" class="data row6 col2" >Yes</td>
#       <td id="T_b4c55_row6_col3" class="data row6 col3" >Yes</td>
#       <td id="T_b4c55_row6_col4" class="data row6 col4" >Yes</td>
#       <td id="T_b4c55_row6_col5" class="data row6 col5" >No</td>
#       <td id="T_b4c55_row6_col6" class="data row6 col6" >No</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b4c55_row7_col0" class="data row7 col0" >west-midlands</td>
#       <td id="T_b4c55_row7_col1" class="data row7 col1" >Yes</td>
#       <td id="T_b4c55_row7_col2" class="data row7 col2" >Yes</td>
#       <td id="T_b4c55_row7_col3" class="data row7 col3" >Yes</td>
#       <td id="T_b4c55_row7_col4" class="data row7 col4" >Yes</td>
#       <td id="T_b4c55_row7_col5" class="data row7 col5" >Yes</td>
#       <td id="T_b4c55_row7_col6" class="data row7 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b4c55_row8_col0" class="data row8 col0" >metropolitan</td>
#       <td id="T_b4c55_row8_col1" class="data row8 col1" >Yes</td>
#       <td id="T_b4c55_row8_col2" class="data row8 col2" >Yes</td>
#       <td id="T_b4c55_row8_col3" class="data row8 col3" >Yes</td>
#       <td id="T_b4c55_row8_col4" class="data row8 col4" >Yes</td>
#       <td id="T_b4c55_row8_col5" class="data row8 col5" >No</td>
#       <td id="T_b4c55_row8_col6" class="data row8 col6" >No</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4c55_row9_col0" class="data row9 col0" >northumbria</td>
#       <td id="T_b4c55_row9_col1" class="data row9 col1" >Yes</td>
#       <td id="T_b4c55_row9_col2" class="data row9 col2" >Yes</td>
#       <td id="T_b4c55_row9_col3" class="data row9 col3" >Yes</td>
#       <td id="T_b4c55_row9_col4" class="data row9 col4" >Yes</td>
#       <td id="T_b4c55_row9_col5" class="data row9 col5" >Yes</td>
#       <td id="T_b4c55_row9_col6" class="data row9 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b4c55_row10_col0" class="data row10 col0" >leicestershire</td>
#       <td id="T_b4c55_row10_col1" class="data row10 col1" >Yes</td>
#       <td id="T_b4c55_row10_col2" class="data row10 col2" >Yes</td>
#       <td id="T_b4c55_row10_col3" class="data row10 col3" >Yes</td>
#       <td id="T_b4c55_row10_col4" class="data row10 col4" >Yes</td>
#       <td id="T_b4c55_row10_col5" class="data row10 col5" >Yes</td>
#       <td id="T_b4c55_row10_col6" class="data row10 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b4c55_row11_col0" class="data row11 col0" >staffordshire</td>
#       <td id="T_b4c55_row11_col1" class="data row11 col1" >Yes</td>
#       <td id="T_b4c55_row11_col2" class="data row11 col2" >Yes</td>
#       <td id="T_b4c55_row11_col3" class="data row11 col3" >Yes</td>
#       <td id="T_b4c55_row11_col4" class="data row11 col4" >Yes</td>
#       <td id="T_b4c55_row11_col5" class="data row11 col5" >Yes</td>
#       <td id="T_b4c55_row11_col6" class="data row11 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_b4c55_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b4c55_row12_col0" class="data row12 col0" >city-of-london</td>
#       <td id="T_b4c55_row12_col1" class="data row12 col1" >Yes</td>
#       <td id="T_b4c55_row12_col2" cla

# %% [markdown]
# # ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
# รายการลิสต์ของไฟล์ที่เลือกสำหรับแต่ละเดือน
all_selected_files = [select_files_01, select_files_02, select_files_03, select_files_04, select_files_05]
data_all_paths = [data_all_01, data_all_02, data_all_03, data_all_04, data_all_05]

# สร้างลิสต์ว่างเพื่อเก็บ dataframes
df_list = []

# วนลูปผ่านข้อมูลของแต่ละเดือน
for month_files, month_path in zip(all_selected_files, data_all_paths):
    # วนลูปผ่านไฟล์ที่เลือกในแต่ละเดือน
    for file_name in month_files:
        file_path = os.path.join(month_path, file_name)
        # แยกชื่อเมืองออกจากชื่อไฟล์
        city_name = file_name.split('-stop-and-search')[0].split('-', 2)[-1]
        try:
            # อ่านไฟล์ CSV
            df = pd.read_csv(file_path)
            # เพิ่มคอลัมน์ 'City'
            df['City'] = city_name
            # เพิ่ม dataframe ไปยังลิสต์
            df_list.append(df)
        except Exception as e:
            print(f"ข้อผิดพลาดในการอ่านไฟล์ {file_path}: {e}")

# นำ dataframes ทั้งหมดมารวมกันเป็น dataframe เดียว
if df_list:
    all_data_df = pd.concat(df_list, ignore_index=True)

    # กรองข้อมูลเฉพาะบันทึกการหยุดตรวจค้นที่มีเชื้อชาติเป็น 'Asian'
    asian_stop_and_search = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

    # นับจำนวนเหตุการณ์หยุดตรวจค้นของคน Asian ในแต่ละเมือง
    asian_counts_by_city = asian_stop_and_search['City'].value_counts().reset_index()
    asian_counts_by_city.columns = ['City', 'Asian_Stop_and_Search_Count']

    # ค้นหาเมืองที่มีจำนวนน้อยที่สุดและมากที่สุด
    min_city = asian_counts_by_city.loc[asian_counts_by_city['Asian_Stop_and_Search_Count'].idxmin()]
    max_city = asian_counts_by_city.loc[asian_counts_by_city['Asian_Stop_and_Search_Count'].idxmax()]

    # สมมติว่า all_data_df, df_cities, min_city, และ max_city มีอยู่จากการทำงานก่อนหน้า

# ดึงรายการเมืองที่มีข้อมูลครบทั้ง 5 เดือนจาก DataFrame df_cities
try:
    รายการเมือง_ครบ_5_เดือน = df_cities[df_cities['Present in all 5 months'] == 'Yes']['City'].tolist()
except NameError:
    print("ข้อผิดพลาด: 'df_cities' ยังไม่ได้ถูกกำหนด กรุณารันเซลล์ที่ระบุเมืองที่มีข้อมูลครบทุกเดือนก่อน")
    รายการเมือง_ครบ_5_เดือน = [] # กำหนดเป็นรายการว่างเพื่อป้องกันข้อผิดพลาดเพิ่มเติม

if รายการเมือง_ครบ_5_เดือน:
    # กรอง DataFrame หลักเพื่อรวมเฉพาะข้อมูลจากเมืองที่มีข้อมูลครบทั้ง 5 เดือน
    ข้อมูลเมืองที่เชื่อถือได้_df = all_data_df[all_data_df['City'].isin(รายการเมือง_ครบ_5_เดือน)]

    # กรองสำหรับบันทึกการหยุดตรวจค้นที่เชื้อชาติเป็น 'Asian'
    ข้อมูลคนเอเชีย_เมืองที่เชื่อถือได้ = ข้อมูลเมืองที่เชื่อถือได้_df[ข้อมูลเมืองที่เชื่อถือได้_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

    # นับจำนวนเหตุการณ์หยุดตรวจค้นคน Asian ต่อเมืองในเมืองที่เชื่อถือได้
    จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้ = ข้อมูลคนเอเชีย_เมืองที่เชื่อถือได้['City'].value_counts().reset_index()
    จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้.columns = ['เมือง', 'จำนวนการหยุดตรวจค้น_คนเอเชีย']

    # ค้นหาเมืองที่มีจำนวนน้อยที่สุดและมากที่สุดในกลุ่มเมืองที่เชื่อถือได้
    เมือง_น้อยที่สุด_เชื่อถือได้ = จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้.loc[จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้['จำนวนการหยุดตรวจค้น_คนเอเชีย'].idxmin()]
    เมือง_มากที่สุด_เชื่อถือได้ = จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้.loc[จำนวนคนเอเชีย_ต่อเมือง_เชื่อถือได้['จำนวนการหยุดตรวจค้น_คนเอเชีย'].idxmax()]

    print("--- เปรียบเทียบผลลัพธ์ ---")

    print("\nผลลัพธ์จากการพิจารณาเมืองทั้งหมด (ที่ปรากฏในอย่างน้อยหนึ่งเดือน):")
    # สมมติว่า min_city และ max_city มีอยู่
    try:
        print(f"📉 เมืองที่มีจำนวนการหยุดตรวจค้นน้อยที่สุด: {min_city['City']}, จำนวนครั้ง: {min_city['Asian_Stop_and_Search_Count']} ครั้ง")
        print(f"📈 เมืองที่มีจำนวนการหยุดตรวจค้นมากที่สุด: {max_city['City']}, จำนวนครั้ง: {max_city['Asian_Stop_and_Search_Count']} ครั้ง")
    except NameError:
        print("ข้อผิดพลาด: 'min_city' หรือ 'max_city' ยังไม่ได้ถูกกำหนด กรุณารันเซลล์ที่คำนวณค่าเหล่านี้สำหรับเมืองทั้งหมดก่อน")


    print("\nผลลัพธ์จากการพิจารณาเฉพาะเมืองที่มีข้อมูลครบทั้ง 5 เดือน:")
    print(f"📉 เมืองที่มีจำนวนการหยุดตรวจค้นน้อยที่สุด: {เมือง_น้อยที่สุด_เชื่อถือได้['เมือง']}, จำนวนครั้ง: {เมือง_น้อยที่สุด_เชื่อถือได้['จำนวนการหยุดตรวจค้น_คนเอเชีย']} ครั้ง")
    print(f"📈 เมืองที่มีจำนวนการหยุดตรวจค้นมากที่สุด: {เมือง_มากที่สุด_เชื่อถือได้['เมือง']}, จำนวนครั้ง: {เมือง_มากที่สุด_เชื่อถือได้['จำนวนการหยุดตรวจค้น_คนเอเชีย']} ครั้ง")

else:
    print("ไม่สามารถทำการวิเคราะห์ได้ เนื่องจากไม่มีรายชื่อเมืองที่มีข้อมูลครบ 5 เดือน หรือมีข้อผิดพลาดในการดึงข้อมูลรายชื่อเมือง")
# Out:
# --- เปรียบเทียบผลลัพธ์ ---
#
# ผลลัพธ์จากการพิจารณาเมืองทั้งหมด (ที่ปรากฏในอย่างน้อยหนึ่งเดือน):
# 📉 เมืองที่มีจำนวนการหยุดตรวจค้นน้อยที่สุด: durham, จำนวนครั้ง: 5 ครั้ง
# 📈 เมืองที่มีจำนวนการหยุดตรวจค้นมากที่สุด: west-midlands, จำนวนครั้ง: 2104 ครั้ง
#
# ผลลัพธ์จากการพิจารณาเฉพาะเมืองที่มีข้อมูลครบทั้ง 5 เดือน:
# 📉 เมืองที่มีจำนวนการหยุดตรวจค้นน้อยที่สุด: durham, จำนวนครั้ง: 5 ครั้ง
# 📈 เมืองที่มีจำนวนการหยุดตรวจค้นมากที่สุด: west-midlands, จำนวนครั้ง: 2104 ครั้ง

# %% [markdown]
# ## ตารางดูจำนวนคนAsia ในแต่ละเมือง ข้อมูลไม่ครบบางเมือง

# %%
# ตรวจสอบให้แน่ใจว่าคอลัมน์ 'Date' อยู่ในรูปแบบ datetime
all_data_df['Date'] = pd.to_datetime(all_data_df['Date'], errors='coerce')

# แยกเดือนและปีและแปลงเป็นสตริง
all_data_df['Month_Year'] = all_data_df['Date'].dt.to_period('M').astype(str)


# กรองข้อมูลสำหรับบันทึกการหยุดตรวจค้นที่เชื้อชาติเป็น 'Asian'
asian_stop_and_search = all_data_df[all_data_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# จัดกลุ่มตามเมืองและเดือน/ปี และนับจำนวนเหตุการณ์
asian_monthly_counts = asian_stop_and_search.groupby(['City', 'Month_Year']).size().reset_index(name='Asian_Stop_and_Search_Count')

# Pivot ตารางเพื่อให้เมืองเป็นแถวและเดือนเป็นคอลัมน์
asian_monthly_pivot = asian_monthly_counts.pivot_table(
    index='City',
    columns='Month_Year',
    values='Asian_Stop_and_Search_Count'
).fillna(0).astype(int) # เติมค่าที่หายไปด้วย 0 และแปลงเป็นจำนวนเต็ม

# เพิ่มคอลัมน์ยอดรวม
asian_monthly_pivot['Total'] = asian_monthly_pivot.sum(axis=1)

# กำหนดฟังก์ชันสำหรับไฮไลท์ค่าต่ำสุดและสูงสุดในคอลัมน์ 'Total'
def highlight_min_max_total(s):
    is_min = s == s.min()
    is_max = s == s.max()
    return ['background-color: green' if v_max or v_min else '' for v_min, v_max in zip(is_min, is_max)]


print("จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมืองแยกตามเดือนพร้อมยอดรวมและไฮไลท์:")

# ใช้ไฮไลท์กับคอลัมน์ 'Total'
styled_df = asian_monthly_pivot.style.apply(highlight_min_max_total, subset=['Total'])

display(styled_df)
# Out:
# /tmp/ipython-input-3630920935.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   all_data_df['Month_Year'] = all_data_df['Date'].dt.to_period('M').astype(str)
# จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมืองแยกตามเดือนพร้อมยอดรวมและไฮไลท์:
# <style type="text/css">
# #T_0814f_row11_col5, #T_0814f_row36_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_0814f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Month_Year</th>
#       <th id="T_0814f_level0_col0" class="col_heading level0 col0" >2025-01</th>
#       <th id="T_0814f_level0_col1" class="col_heading level0 col1" >2025-02</th>
#       <th id="T_0814f_level0_col2" class="col_heading level0 col2" >2025-03</th>
#       <th id="T_0814f_level0_col3" class="col_heading level0 col3" >2025-04</th>
#       <th id="T_0814f_level0_col4" class="col_heading level0 col4" >2025-05</th>
#       <th id="T_0814f_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0814f_level0_row0" class="row_heading level0 row0" >avon-and-somerset</th>
#       <td id="T_0814f_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_0814f_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_0814f_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_0814f_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_0814f_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_0814f_row0_col5" class="data row0 col5" >54</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row1" class="row_heading level0 row1" >bedfordshire</th>
#       <td id="T_0814f_row1_col0" class="data row1 col0" >69</td>
#       <td id="T_0814f_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_0814f_row1_col2" class="data row1 col2" >71</td>
#       <td id="T_0814f_row1_col3" class="data row1 col3" >60</td>
#       <td id="T_0814f_row1_col4" class="data row1 col4" >71</td>
#       <td id="T_0814f_row1_col5" class="data row1 col5" >322</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row2" class="row_heading level0 row2" >btp</th>
#       <td id="T_0814f_row2_col0" class="data row2 col0" >133</td>
#       <td id="T_0814f_row2_col1" class="data row2 col1" >85</td>
#       <td id="T_0814f_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_0814f_row2_col3" class="data row2 col3" >98</td>
#       <td id="T_0814f_row2_col4" class="data row2 col4" >92</td>
#       <td id="T_0814f_row2_col5" class="data row2 col5" >524</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row3" class="row_heading level0 row3" >cambridgeshire</th>
#       <td id="T_0814f_row3_col0" class="data row3 col0" >35</td>
#       <td id="T_0814f_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_0814f_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_0814f_row3_col3" class="data row3 col3" >28</td>
#       <td id="T_0814f_row3_col4" class="data row3 col4" >16</td>
#       <td id="T_0814f_row3_col5" class="data row3 col5" >120</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row4" class="row_heading level0 row4" >cheshire</th>
#       <td id="T_0814f_row4_col0" class="data row4 col0" >18</td>
#       <td id="T_0814f_row4_col1" class="data row4 col1" >36</td>
#       <td id="T_0814f_row4_col2" class="data row4 col2" >25</td>
#       <td id="T_0814f_row4_col3" class="data row4 col3" >31</td>
#       <td id="T_0814f_row4_col4" class="data row4 col4" >39</td>
#       <td id="T_0814f_row4_col5" class="data row4 col5" >149</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row5" class="row_heading level0 row5" >city-of-london</th>
#       <td id="T_0814f_row5_col0" class="data row5 col0" >19</td>
#       <td id="T_0814f_row5_col1" class="data row5 col1" >18</td>
#       <td id="T_0814f_row5_col2" class="data row5 col2" >19</td>
#       <td id="T_0814f_row5_col3" class="data row5 col3" >9</td>
#       <td id="T_0814f_row5_col4" class="data row5 col4" >19</td>
#       <td id="T_0814f_row5_col5" class="data row5 col5" >84</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row6" class="row_heading level0 row6" >cleveland</th>
#       <td id="T_0814f_row6_col0" class="data row6 col0" >17</td>
#       <td id="T_0814f_row6_col1" class="data row6 col1" >22</td>
#       <td id="T_0814f_row6_col2" class="data row6 col2" >28</td>
#       <td id="T_0814f_row6_col3" class="data row6 col3" >26</td>
#       <td id="T_0814f_row6_col4" class="data row6 col4" >32</td>
#       <td id="T_0814f_row6_col5" class="data row6 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row7" class="row_heading level0 row7" >cumbria</th>
#       <td id="T_0814f_row7_col0" class="data row7 col0" >25</td>
#       <td id="T_0814f_row7_col1" class="data row7 col1" >18</td>
#       <td id="T_0814f_row7_col2" class="data row7 col2" >16</td>
#       <td id="T_0814f_row7_col3" class="data row7 col3" >20</td>
#       <td id="T_0814f_row7_col4" class="data row7 col4" >15</td>
#       <td id="T_0814f_row7_col5" class="data row7 col5" >94</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row8" class="row_heading level0 row8" >derbyshire</th>
#       <td id="T_0814f_row8_col0" class="data row8 col0" >23</td>
#       <td id="T_0814f_row8_col1" class="data row8 col1" >21</td>
#       <td id="T_0814f_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_0814f_row8_col3" class="data row8 col3" >22</td>
#       <td id="T_0814f_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_0814f_row8_col5" class="data row8 col5" >83</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row9" class="row_heading level0 row9" >devon-and-cornwall</th>
#       <td id="T_0814f_row9_col0" class="data row9 col0" >7</td>
#       <td id="T_0814f_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_0814f_row9_col2" class="data row9 col2" >8</td>
#       <td id="T_0814f_row9_col3" class="data row9 col3" >6</td>
#       <td id="T_0814f_row9_col4" class="data row9 col4" >6</td>
#       <td id="T_0814f_row9_col5" class="data row9 col5" >35</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row10" class="row_heading level0 row10" >dorset</th>
#       <td id="T_0814f_row10_col0" class="data row10 col0" >7</td>
#       <td id="T_0814f_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_0814f_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_0814f_row10_col3" class="data row10 col3" >4</td>
#       <td id="T_0814f_row10_col4" class="data row10 col4" >3</td>
#       <td id="T_0814f_row10_col5" class="data row10 col5" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row11" class="row_heading level0 row11" >durham</th>
#       <td id="T_0814f_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_0814f_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_0814f_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_0814f_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_0814f_row11_col4" class="data row11 col4" >2</td>
#       <td id="T_0814f_row11_col5" class="data row11 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row12" class="row_heading level0 row12" >dyfed-powys</th>
#       <td id="T_0814f_row12_col0" class="data row12 col0" >3</td>
#       <td id="T_0814f_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_0814f_row12_col2" class="data row12 col2" >12</td>
#       <td id="T_0814f_row12_col3" class="data row12 col3" >5</td>
#       <td id="T_0814f_row12_col4" class="data row12 col4" >2</td>
#       <td id="T_0814f_row12_col5" class="data row12 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_0814f_level0_row13" class="row_heading level0 row13" >essex</th>
#       <td id="T_0814f_row13_col0" class="data row13 col0" >36</td>
#       <td id="T_0814f_row13_col1" class="data row13 col1" >44</td>
#       <td id="T_0814f_row13_col2" class="data row13 col2" >33</td>
#       <td id="T_0814f_row13_col3" class="data row13 col3" >25</td>
#       <td id="T_0814f_row13_col4" class="data row13 col4" >32</td>
#       <td id="T_0814f_row13_col5" class="data row13 col5" >170</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## ตารางดูจำนวนคนAsia ในแต่ละเมือง ข้อมูลครบทุกเมืองในแต่ละเดือน ตัดเมือง merseyside, derbyshire และ metropolitan

# %%
# สมมติว่า ข้อมูลเมืองที่เชื่อถือได้_df มีอยู่จากการทำงานก่อนหน้า
# หากไม่มี โปรดตรวจสอบให้แน่ใจว่าได้รันเซลล์ที่สร้าง ข้อมูลเมืองที่เชื่อถือได้_df ก่อน

# ตรวจสอบให้แน่ใจว่าคอลัมน์ 'Date' อยู่ในรูปแบบ datetime ใน DataFrame ที่ถูกกรองแล้ว
ข้อมูลเมืองที่เชื่อถือได้_df['Date'] = pd.to_datetime(ข้อมูลเมืองที่เชื่อถือได้_df['Date'], errors='coerce')

# แยกเดือนและปีและแปลงเป็นสตริง
ข้อมูลเมืองที่เชื่อถือได้_df['Month_Year'] = ข้อมูลเมืองที่เชื่อถือได้_df['Date'].dt.to_period('M').astype(str)

# กรองสำหรับบันทึกการหยุดตรวจค้นที่เชื้อชาติเป็น 'Asian' ใน DataFrame ที่ถูกกรองแล้ว
ข้อมูลคนเอเชีย_เมืองที่เชื่อถือได้_รายเดือน = ข้อมูลเมืองที่เชื่อถือได้_df[ข้อมูลเมืองที่เชื่อถือได้_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# จัดกลุ่มตามเมืองและเดือน/ปี และนับจำนวนเหตุการณ์
จำนวนคนเอเชีย_รายเดือน_เมืองเชื่อถือได้ = ข้อมูลคนเอเชีย_เมืองที่เชื่อถือได้_รายเดือน.groupby(['City', 'Month_Year']).size().reset_index(name='Asian_Stop_and_Search_Count')

# Pivot ตารางเพื่อให้เมืองเป็นแถวและเดือนเป็นคอลัมน์
ตารางรายเดือน_เมืองเชื่อถือได้ = จำนวนคนเอเชีย_รายเดือน_เมืองเชื่อถือได้.pivot_table(
    index='City',
    columns='Month_Year',
    values='Asian_Stop_and_Search_Count'
).fillna(0).astype(int) # เติมค่าที่หายไปด้วย 0 และแปลงเป็นจำนวนเต็ม

# เพิ่มคอลัมน์ยอดรวม
ตารางรายเดือน_เมืองเชื่อถือได้['Total'] = ตารางรายเดือน_เมืองเชื่อถือได้.sum(axis=1)

# กำหนดฟังก์ชันสำหรับไฮไลท์ค่าต่ำสุดและสูงสุดในคอลัมน์ 'Total'
def highlight_min_max_total(s):
    is_min = s == s.min()
    is_max = s == s.max()
    return ['background-color: green' if v_max or v_min else '' for v_min, v_max in zip(is_min, is_max)]


print("จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมือง (ข้อมูลครบ 5 เดือน) แยกตามเดือนพร้อมยอดรวมและไฮไลท์:")

# ใช้ไฮไลท์กับคอลัมน์ 'Total'
styled_ตารางรายเดือน_เมืองเชื่อถือได้ = ตารางรายเดือน_เมืองเชื่อถือได้.style.apply(highlight_min_max_total, subset=['Total'])

display(styled_ตารางรายเดือน_เมืองเชื่อถือได้)
# Out:
# จำนวนเหตุการณ์หยุดตรวจค้นคน Asian ในแต่ละเมือง (ข้อมูลครบ 5 เดือน) แยกตามเดือนพร้อมยอดรวมและไฮไลท์:
# /tmp/ipython-input-25699694.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ข้อมูลเมืองที่เชื่อถือได้_df['Date'] = pd.to_datetime(ข้อมูลเมืองที่เชื่อถือได้_df['Date'], errors='coerce')
# /tmp/ipython-input-25699694.py:8: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   ข้อมูลเมืองที่เชื่อถือได้_df['Month_Year'] = ข้อมูลเมืองที่เชื่อถือได้_df['Date'].dt.to_period('M').astype(str)
# /tmp/ipython-input-25699694.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ข้อมูลเมืองที่เชื่อถือได้_df['Month_Year'] = ข้อมูลเมืองที่เชื่อถือได้_df['Date'].dt.to_period('M').astype(str)
# <style type="text/css">
# #T_4a4c9_row10_col5, #T_4a4c9_row33_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_4a4c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Month_Year</th>
#       <th id="T_4a4c9_level0_col0" class="col_heading level0 col0" >2025-01</th>
#       <th id="T_4a4c9_level0_col1" class="col_heading level0 col1" >2025-02</th>
#       <th id="T_4a4c9_level0_col2" class="col_heading level0 col2" >2025-03</th>
#       <th id="T_4a4c9_level0_col3" class="col_heading level0 col3" >2025-04</th>
#       <th id="T_4a4c9_level0_col4" class="col_heading level0 col4" >2025-05</th>
#       <th id="T_4a4c9_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a4c9_level0_row0" class="row_heading level0 row0" >avon-and-somerset</th>
#       <td id="T_4a4c9_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_4a4c9_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_4a4c9_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_4a4c9_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_4a4c9_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_4a4c9_row0_col5" class="data row0 col5" >54</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row1" class="row_heading level0 row1" >bedfordshire</th>
#       <td id="T_4a4c9_row1_col0" class="data row1 col0" >69</td>
#       <td id="T_4a4c9_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_4a4c9_row1_col2" class="data row1 col2" >71</td>
#       <td id="T_4a4c9_row1_col3" class="data row1 col3" >60</td>
#       <td id="T_4a4c9_row1_col4" class="data row1 col4" >71</td>
#       <td id="T_4a4c9_row1_col5" class="data row1 col5" >322</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row2" class="row_heading level0 row2" >btp</th>
#       <td id="T_4a4c9_row2_col0" class="data row2 col0" >133</td>
#       <td id="T_4a4c9_row2_col1" class="data row2 col1" >85</td>
#       <td id="T_4a4c9_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_4a4c9_row2_col3" class="data row2 col3" >98</td>
#       <td id="T_4a4c9_row2_col4" class="data row2 col4" >92</td>
#       <td id="T_4a4c9_row2_col5" class="data row2 col5" >524</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row3" class="row_heading level0 row3" >cambridgeshire</th>
#       <td id="T_4a4c9_row3_col0" class="data row3 col0" >35</td>
#       <td id="T_4a4c9_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_4a4c9_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_4a4c9_row3_col3" class="data row3 col3" >28</td>
#       <td id="T_4a4c9_row3_col4" class="data row3 col4" >16</td>
#       <td id="T_4a4c9_row3_col5" class="data row3 col5" >120</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row4" class="row_heading level0 row4" >cheshire</th>
#       <td id="T_4a4c9_row4_col0" class="data row4 col0" >18</td>
#       <td id="T_4a4c9_row4_col1" class="data row4 col1" >36</td>
#       <td id="T_4a4c9_row4_col2" class="data row4 col2" >25</td>
#       <td id="T_4a4c9_row4_col3" class="data row4 col3" >31</td>
#       <td id="T_4a4c9_row4_col4" class="data row4 col4" >39</td>
#       <td id="T_4a4c9_row4_col5" class="data row4 col5" >149</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row5" class="row_heading level0 row5" >city-of-london</th>
#       <td id="T_4a4c9_row5_col0" class="data row5 col0" >19</td>
#       <td id="T_4a4c9_row5_col1" class="data row5 col1" >18</td>
#       <td id="T_4a4c9_row5_col2" class="data row5 col2" >19</td>
#       <td id="T_4a4c9_row5_col3" class="data row5 col3" >9</td>
#       <td id="T_4a4c9_row5_col4" class="data row5 col4" >19</td>
#       <td id="T_4a4c9_row5_col5" class="data row5 col5" >84</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row6" class="row_heading level0 row6" >cleveland</th>
#       <td id="T_4a4c9_row6_col0" class="data row6 col0" >17</td>
#       <td id="T_4a4c9_row6_col1" class="data row6 col1" >22</td>
#       <td id="T_4a4c9_row6_col2" class="data row6 col2" >28</td>
#       <td id="T_4a4c9_row6_col3" class="data row6 col3" >26</td>
#       <td id="T_4a4c9_row6_col4" class="data row6 col4" >32</td>
#       <td id="T_4a4c9_row6_col5" class="data row6 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row7" class="row_heading level0 row7" >cumbria</th>
#       <td id="T_4a4c9_row7_col0" class="data row7 col0" >25</td>
#       <td id="T_4a4c9_row7_col1" class="data row7 col1" >18</td>
#       <td id="T_4a4c9_row7_col2" class="data row7 col2" >16</td>
#       <td id="T_4a4c9_row7_col3" class="data row7 col3" >20</td>
#       <td id="T_4a4c9_row7_col4" class="data row7 col4" >15</td>
#       <td id="T_4a4c9_row7_col5" class="data row7 col5" >94</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row8" class="row_heading level0 row8" >devon-and-cornwall</th>
#       <td id="T_4a4c9_row8_col0" class="data row8 col0" >7</td>
#       <td id="T_4a4c9_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_4a4c9_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_4a4c9_row8_col3" class="data row8 col3" >6</td>
#       <td id="T_4a4c9_row8_col4" class="data row8 col4" >6</td>
#       <td id="T_4a4c9_row8_col5" class="data row8 col5" >35</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row9" class="row_heading level0 row9" >dorset</th>
#       <td id="T_4a4c9_row9_col0" class="data row9 col0" >7</td>
#       <td id="T_4a4c9_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_4a4c9_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_4a4c9_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_4a4c9_row9_col4" class="data row9 col4" >3</td>
#       <td id="T_4a4c9_row9_col5" class="data row9 col5" >18</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row10" class="row_heading level0 row10" >durham</th>
#       <td id="T_4a4c9_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_4a4c9_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_4a4c9_row10_col2" class="data row10 col2" >2</td>
#       <td id="T_4a4c9_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_4a4c9_row10_col4" class="data row10 col4" >2</td>
#       <td id="T_4a4c9_row10_col5" class="data row10 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row11" class="row_heading level0 row11" >dyfed-powys</th>
#       <td id="T_4a4c9_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_4a4c9_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_4a4c9_row11_col2" class="data row11 col2" >12</td>
#       <td id="T_4a4c9_row11_col3" class="data row11 col3" >5</td>
#       <td id="T_4a4c9_row11_col4" class="data row11 col4" >2</td>
#       <td id="T_4a4c9_row11_col5" class="data row11 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row12" class="row_heading level0 row12" >essex</th>
#       <td id="T_4a4c9_row12_col0" class="data row12 col0" >36</td>
#       <td id="T_4a4c9_row12_col1" class="data row12 col1" >44</td>
#       <td id="T_4a4c9_row12_col2" class="data row12 col2" >33</td>
#       <td id="T_4a4c9_row12_col3" class="data row12 col3" >25</td>
#       <td id="T_4a4c9_row12_col4" class="data row12 col4" >32</td>
#       <td id="T_4a4c9_row12_col5" class="data row12 col5" >170</td>
#     </tr>
#     <tr>
#       <th id="T_4a4c9_level0_row13" class="row_heading level0 row13" >gloucestershire</th>
#       <td id="T_4a4c9_row13_col0" class="data row13 col0" >4</td>
#       <td id="T_4a4c9_row13_col1" class="data row13 col1" >11</td>
#       <td id="T_4a4c9_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_4a4c9_row13_col3" class="data row13 col3" >4</td>
#       <td id="T_4a4c9_row13_col4" class="data row13 col4" >2</td>
#       <td id="T_4a4c9_row13_col5" class="data row13 col5" >27</td>
#     </tr>
#     <t
