# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanyarat281-6/dataviz2025/blob/main/Visualize_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การแสดงผลการกระจายของข้อมูล

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_stopandsearch = '/content/drive/MyDrive/Python&datavizz2025/data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# 0                        Arrest                              False
# 1  A no further action disposal                                NaN
# 2  A no further action disposal                                NaN
# 3  A no further action disposal                                NaN
# 4  A no further action disposal                                NaN
#
#    Removal of more than just outer clothing
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False

# %% [markdown]
# แปลงค่า Gender และ Age range เป็นจำนวนจริง

# %%
stopandsearch_df.groupby('Gender').count()
# Out:
#         Type  Date  Part of a policing operation  Policing operation  \
# Gender
# Female    40    40                            40                   0
# Male     287   287                           287                   0
#
#         Latitude  Longitude  Age range  Self-defined ethnicity  \
# Gender
# Female        34         34         40                      39
# Male         240        240        278                     280
#
#         Officer-defined ethnicity  Legislation  Object of search  Outcome  \
# Gender
# Female                         37           40                40       40
# Male                          276          287               287      287
#
#         Outcome linked to object of search  \
# Gender
# Female                                  10
# Male                                   107
#
#         Removal of more than just outer clothing
# Gender
# Female                                        40
# Male                                         287

# %%
stopandsearch_df.groupby('Age range').count()
# Out:
#            Type  Date  Part of a policing operation  Policing operation  \
# Age range
# 10-17        45    45                            45                   0
# 18-24        99    99                            99                   0
# 25-34        80    80                            80                   0
# over 34     126   126                           126                   0
# under 10      1     1                             1                   0
#
#            Latitude  Longitude  Gender  Self-defined ethnicity  \
# Age range
# 10-17            39         39      43                      42
# 18-24            84         84      84                      96
# 25-34            63         63      71                      79
# over 34         104        104     119                     122
# under 10          1          1       1                       1
#
#            Officer-defined ethnicity  Legislation  Object of search  Outcome  \
# Age range
# 10-17                             42           45                45       45
# 18-24                             97           99                99       99
# 25-34                             75           80                80       80
# over 34                          122          126               126      126
# under 10                           1            1                 1        1
#
#            Outcome linked to object of search  \
# Age range
# 10-17                                      17
# 18-24                                      41
# 25-34                                      32
# over 34                                    40
# under 10                                    0
#
#            Removal of more than just outer clothing
# Age range
# 10-17                                            45
# 18-24                                            99
# 25-34                                            80
# over 34                                         126
# under 10                                          1

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %%
stopandsearch_df_dropna = stopandsearch_df.dropna(subset=['Age range','Gender'])

# %%
stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Female': 1, 'Male': 35})
stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10': 10, 'over 34': 34,
                                                                                     '25-34':30,'18-24':21,'10-17':14})
# Out:
# /tmp/ipython-input-3376285857.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Female': 1, 'Male': 35})
# /tmp/ipython-input-3376285857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Female': 1, 'Male': 35})
# /tmp/ipython-input-3376285857.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10': 10, 'over 34': 34,
# /tmp/ipython-input-3376285857.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10': 10, 'over 34': 34,

# %% [markdown]
# ### สร้าง list ของ ตัวเลข random number ที่เป็น normal distribution

# %%
import numpy as np
list_of_rn = np.random.normal(loc=1, scale=0.1, size=len(stopandsearch_df_dropna))

# %%
plt.hist(list_of_rn);

# %%
hist_out = plt.hist(list_of_rn,bins=20)

# %%
hist_out
# Out:
# (array([ 2.,  4., 11., 37., 74., 63., 75., 32., 14.,  6.]),
#  array([0.65342018, 0.7145408 , 0.77566143, 0.83678206, 0.89790269,
#         0.95902331, 1.02014394, 1.08126457, 1.1423852 , 1.20350582,
#         1.26462645]),
#  <BarContainer object of 10 artists>)

# %%
stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * list_of_rn
# Out:
# /tmp/ipython-input-864405060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * list_of_rn

# %%
stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'] * np.random.normal(loc=1, scale=0.01, size=len(stopandsearch_df_dropna))
# Out:
# /tmp/ipython-input-2945934892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'] * np.random.normal(loc=1, scale=0.01, size=len(stopandsearch_df_dropna))

# %% [markdown]
# ### ลบค่าที่เป็น outliers

# %%
stopandsearch_df_dropna = stopandsearch_df_dropna[(stopandsearch_df_dropna['Gender']>=0) & (stopandsearch_df_dropna['Gender']<40)]

# %%
stopandsearch_df_dropna.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
# 5  Person search  2025-01-01T10:00:00+00:00                         False
#
#    Policing operation   Latitude  Longitude     Gender  Age range  \
# 0                 NaN  51.881481  -0.413110  34.014543  30.329958
# 2                 NaN  52.132059  -0.296600  32.857495  13.934655
# 3                 NaN  52.132059  -0.296600   1.035824  14.293260
# 4                 NaN  52.132059  -0.296600  36.797182  14.260305
# 5                 NaN  51.895904  -0.444082  33.016950  29.804157
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...
# 5                    Other ethnic group - Not stated
#
#   Officer-defined ethnicity  \
# 0                     Other
# 2                     White
# 3                     White
# 4                     White
# 5                       NaN
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 2  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 3  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 4  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 5              Misuse of Drugs Act 1971 (section 23)   Controlled drugs
#
#                         Outcome Outcome linked to object of search  \
# 0                        Arrest                              False
# 2  A no further action disposal                                NaN
# 3  A no further action disposal                                NaN
# 4  A no further action disposal                                NaN
# 5  A no further action disposal                                NaN
#
#    Removal of more than just outer clothing
# 0                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# 5                                     False

# %%
pd.plotting.parallel_coordinates(stopandsearch_df_dropna[['Gender','Age range','Self-defined ethnicity']],'Self-defined ethnicity')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -1.2))

# %% [markdown]
# # Scatter plot

# %% [markdown]
# ### เปลี่ยนความโปรงไสเพื่อดูข้อมูลที่ทับกัน

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'])

# %% [markdown]
# ###เปลี่ยนสี

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'], c='r',alpha=0.3)

# %% [markdown]
# ### ใช้ค่าสีในการแสดงค่าในคอลัมน์อื่น
#
# ตัวอย่าง column > Officer-defined ethnicity

# %%
  stopandsearch_df.groupby('Officer-defined ethnicity').count()
# Out:
#                            Type  Date  Part of a policing operation  \
# Officer-defined ethnicity
# Asian                        81    81                            81
# Black                        64    64                            64
# Other                         9     9                             9
# White                       199   199                           199
#
#                            Policing operation  Latitude  Longitude  Gender  \
# Officer-defined ethnicity
# Asian                                       0        64         64      75
# Black                                       0        52         52      51
# Other                                       0         6          6       8
# White                                       0       168        168     179
#
#                            Age range  Self-defined ethnicity  Legislation  \
# Officer-defined ethnicity
# Asian                             77                      79           81
# Black                             62                      63           64
# Other                              9                       9            9
# White                            189                     191          199
#
#                            Object of search  Outcome  \
# Officer-defined ethnicity
# Asian                                    81       81
# Black                                    64       64
# Other                                     9        9
# White                                   199      199
#
#                            Outcome linked to object of search  \
# Officer-defined ethnicity
# Asian                                                      30
# Black                                                      26
# Other                                                       5
# White                                                      66
#
#                            Removal of more than just outer clothing
# Officer-defined ethnicity
# Asian                                                            81
# Black                                                            64
# Other                                                             9
# White                                                           199

# %%
stopandsearch_df_dropna['Officer-defined ethnicity'] = stopandsearch_df_dropna['Officer-defined ethnicity'].replace({'Black':0,'Other':1,'Asian':2,'White':3})
# Out:
# /tmp/ipython-input-416912422.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Officer-defined ethnicity'] = stopandsearch_df_dropna['Officer-defined ethnicity'].replace({'Black':0,'Other':1,'Asian':2,'White':3})

# %%
stopandsearch_df_dropna
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# ..                         ...                        ...
# 381              Person search  2025-01-31T21:24:00+00:00
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 2                           False                 NaN  52.132059  -0.296600
# 3                           False                 NaN  52.132059  -0.296600
# 4                           False                 NaN  52.132059  -0.296600
# 5                           False                 NaN  51.895904  -0.444082
# ..                            ...                 ...        ...        ...
# 381                         False                 NaN  52.134841  -0.483243
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 386                         False                 NaN  51.878459  -0.422384
#
#         Gender  Age range                             Self-defined ethnicity  \
# 0    34.014543  30.329958  Mixed/Multiple ethnic groups - Any other Mixed...
# 2    32.857495  13.934655  White - English/Welsh/Scottish/Northern Irish/...
# 3     1.035824  14.293260  White - English/Welsh/Scottish/Northern Irish/...
# 4    36.797182  14.260305  White - English/Welsh/Scottish/Northern Irish/...
# 5    33.016950  29.804157                    Other ethnic group - Not stated
# ..         ...        ...                                                ...
# 381  33.569112  33.752640  Mixed/Multiple ethnic groups - White and Black...
# 382   1.144045  34.431030  White - English/Welsh/Scottish/Northern Irish/...
# 383  35.854126  29.430142  White - English/Welsh/Scottish/Northern Irish/...
# 384  37.887485  33.818845                    Other ethnic group - Not stated
# 386  33.088508  21.070382   Asian/Asian British - Any other Asian background
#
#      Officer-defined ethnicity  \
# 0                          1.0
# 2                          3.0
# 3                          3.0
# 4                          3.0
# 5                          NaN
# ..                         ...
# 381                        0.0
# 382                        3.0
# 383                        3.0
# 384                        3.0
# 386                        2.0
#
#                                            Legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# 5                Misuse of Drugs Act 1971 (section 23)
# ..                                                 ...
# 381  Police and Criminal Evidence Act 1984 (section 1)
# 382  Police and Criminal Evidence Act 1984 (section 1)
# 383  Police and Criminal Evidence Act 1984 (section 1)
# 384  Police and Criminal Evidence Act 1984 (section 1)
# 386              Misuse of Drugs Act 1971 (section 23)
#
#              Object of search                       Outcome  \
# 0           Offensive weapons                        Arrest
# 2           Offensive weapons  A no further action disposal
# 3           Offensive weapons  A no further action disposal
# 4           Offensive weapons  A no further action disposal
# 5            Controlled drugs  A no further action disposal
# ..                        ...                           ...
# 381  Article for use in theft  A no further action disposal
# 382  Article for use in theft  A no further action disposal
# 383  Article for use in theft  A no further action disposal
# 384  Article for use in theft          Community resolution
# 386          Controlled drugs  A no further action disposal
#
#     Outcome linked to object of search  \
# 0                                False
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# ..                                 ...
# 381                              False
# 382                                NaN
# 383                                NaN
# 384                               True
# 386                                NaN
#
#      Removal of more than just outer clothing
# 0                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# ..                                        ...
# 381                                     False
# 382                                     False
# 383                                     False
# 384                                     False
# 386                                     False
#
# [302 rows x 15 columns]

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'], c=stopandsearch_df_dropna['Officer-defined ethnicity'],alpha=0.3)
plt.title('Distributionof Age vs Gender for stop and search (Bedford Jan 2025)')
plt.xlabel('Age range')
plt.ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %% [markdown]
# ## Scatter 2D

# %% [markdown]
# ## scatter - default

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %% [markdown]
# ### color

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c='r')

# %% [markdown]
# ## ใส่สีให้แต่ละจุด

# %%
set(df['Name']) #ดูว่ามีค่าอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
df2
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %% [markdown]
# ### alpha กำหนดความโปร่งแสง

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ใช้ขนาดของ marker แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],s=50*df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=100,c=df2['Name'],alpha=0.5,marker='*')

# %% [markdown]
# ## การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='$S$')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='$E$')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='$I$')

# %% [markdown]
# ###Label-Legend

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df2 = df.copy()
df2['Name']= df2['Name'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
df2.head()
# Out:
# /tmp/ipython-input-2236928856.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Name']= df2['Name'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0          5.1         3.5          1.4         0.2     0
# 1          4.9         3.0          1.4         0.2     0
# 2          4.7         3.2          1.3         0.2     0
# 3          4.6         3.1          1.5         0.2     0
# 4          5.0         3.6          1.4         0.2     0

# %% [markdown]
# ```plt.plot()``` input  ตัวที่ 3 คือ ตัวกำหนดหน้าตาของ marker
#
# 'หน้าตาmarker'-'ลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o--r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o:r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend()

# %% [markdown]
# ### การใส่ชื่อกราฟ และชื่อแกน

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right')
plt.title('Iris flower data distribution') ##ชื่อกราฟ
plt.xlabel('PetalLength') ##ชื่อแกน X
plt.ylabel('PetalWidth'); ##ชื่อแกน y

# %% [markdown]
# ### 3D scatter

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ## Bubble Chart
#
# Scatter plot ที่ใช้ขนาดของ marker ในการสื่อปริมาณของข้อมูล

# %%
plt.scatter(df['PetalLength'][:50],df['SepalLength'][:50],s=150*df['PetalWidth'][100:],c='r',alpha=0.5)

# %% [markdown]
# ### Example

# %% [markdown]
# ### Box-plot

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
O = plt.boxplot(stopandsearch_df['Latitude'].dropna())

# %%
O = plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1,vert=False)

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f153c6aa2d0>,
#   <matplotlib.lines.Line2D at 0x7f153c6aa5a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f153c6aa870>,
#   <matplotlib.lines.Line2D at 0x7f153c6aab40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f153c6a9fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f153c6aae70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f153c6ab440>],
#  'means': [<matplotlib.lines.Line2D at 0x7f153c6ab110>]}

# %%
O['fliers']

# %%
O['fliers'][0]

# %%
dir(O['fliers'][0])
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_callbacks',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_color',
#  '_dash_pattern',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_different_canvas',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_fully_clipped_to_axes',
#  '_gapcolor',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_internal_update',
#  '_invalidx',
#  '_invalidy',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
#  '_linewidth',
#  '_marker',
#  '_markeredgecolor',
#  '_markeredgewidth',
#  '_markerfacecolor',
#  '_markerfacecoloralt',
#  '_markersize',
#  '_markevery',
#  '_mouseover',
#  '_parent_figure',
#  '_path',
#  '_path_effects',
#  '_picker',
#  '_pickradius',
#  '_rasterized',
#  '_remove_method',
#  '_set_alpha_for_array',
#  '_set_gc_clip',
#  '_set_markercolor',
#  '_sketch',
#  '_snap',
#  '_solidcapstyle',
#  '_solidjoinstyle',
#  '_stale',
#  '_sticky_edges',
#  '_subslice',
#  '_subslice_optim_min_size',
#  '_transform',
#  '_transformSet',
#  '_transform_path',
#  '_transformed_path',
#  '_unscaled_dash_pattern',
#  '_update_props',
#  '_update_set_signature_and_docstring',
#  '_url',
#  '_visible',
#  '_x',
#  '_x_filled',
#  '_xorig',
#  '_xy',
#  '_y',
#  '_yorig',
#  'add_callback',
#  'axes',
#  'clipbox',
#  'contains',
#  'convert_xunits',
#  'convert_yunits',
#  'draw',
#  'drawStyleKeys',
#  'drawStyles',
#  'figure',
#  'fillStyles',
#  'filled_markers',
#  'findobj',
#  'format_cursor_data',
#  'get_aa',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_antialiased',
#  'get_bbox',
#  'get_c',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_color',
#  'get_cursor_data',
#  'get_dash_capstyle',
#  'get_dash_joinstyle',
#  'get_data',
#  'get_drawstyle',
#  'get_ds',
#  'get_figure',
#  'get_fillstyle',
#  'get_gapcolor',
#  'get_gid',
#  'get_in_layout',
#  'get_label',
#  'get_linestyle',
#  'get_linewidth',
#  'get_ls',
#  'get_lw',
#  'get_marker',
#  'get_markeredgecolor',
#  'get_markeredgewidth',
#  'get_markerfacecolor',
#  'get_markerfacecoloralt',
#  'get_markersize',
#  'get_markevery',
#  'get_mec',
#  'get_mew',
#  'get_mfc',
#  'get_mfcalt',
#  'get_mouseover',
#  'get_ms',
#  'get_path',
#  'get_path_effects',
#  'get_picker',
#  'get_pickradius',
#  'get_rasterized',
#  'get_sketch_params',
#  'get_snap',
#  'get_solid_capstyle',
#  'get_solid_joinstyle',
#  'get_tightbbox',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xdata',
#  'get_xydata',
#  'get_ydata',
#  'get_zorder',
#  'have_units',
#  'ind_offset',
#  'is_dashed',
#  'is_transform_set',
#  'lineStyles',
#  'markers',
#  'mouseover',
#  'pchanged',
#  'pick',
#  'pickable',
#  'pickradius',
#  'properties',
#  'recache',
#  'recache_always',
#  'remove',
#  'remove_callback',
#  'set',
#  'set_aa',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_antialiased',
#  'set_c',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_color',
#  'set_dash_capstyle',
#  'set_dash_joinstyle',
#  'set_dashes',
#  'set_data',
#  'set_drawstyle',
#  'set_ds',
#  'set_figure',
#  'set_fillstyle',
#  'set_gapcolor',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_linestyle',
#  'set_linewidth',
#  'set_ls',
#  'set_lw',
#  'set_marker',
#  'set_markeredgecolor',
#  'set_markeredgewidth',
#  'set_markerfacecolor',
#  'set_markerfacecoloralt',
#  'set_markersize',
#  'set_markevery',
#  'set_mec',
#  'set_mew',
#  'set_mfc',
#  'set_mfcalt',
#  'set_mouseover',
#  'set_ms',
#  'set_path_effects',
#  'set_picker',
#  'set_pickradius',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_solid_capstyle',
#  'set_solid_joinstyle',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xdata',
#  'set_ydata',
#  'set_zorder',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'update',
#  'update_from',
#  'zorder']

# %%
O['fliers'][0].get_ydata()
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
O['fliers'][0].get_xdata()
# Out:
# array([1., 1., 1., 1.])

# %%
stopandsearch_df[(stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[0]) |
                          (stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[1])]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /tmp/ipython-input-774730131.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   stopandsearch_df[(stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[0]) |
# /tmp/ipython-input-774730131.py:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   (stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[1])]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-774730131.py in <cell line: 0>()
# ----> 1 stopandsearch_df[(stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[0]) |
#       2                           (stopandsearch_df['Latitude']==[0]['fliers'][0].get_xdata()[1])]
#
# TypeError: list indices must be integers or slices, not str

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)

# %%
O
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f7f44299ed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7f44220f10>,
#   <matplotlib.lines.Line2D at 0x7f7f44226490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7f4422e490>],
#  'means': [<matplotlib.lines.Line2D at 0x7f7f44226f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7f44226a10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f7f44220490>,
#   <matplotlib.lines.Line2D at 0x7f7f442209d0>]}

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %%
plt.subplot(1,2,1)
plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1,vert=False,showmeans=True,meanline=True)
plt.title('Lat')
plt.subplot(1,2,2)
plt.boxplot(stopandsearch_df['Longitude'].dropna(),whis=1,vert=False)
plt.title('Long')
# Out:
# Text(0.5, 1.0, 'Long')

# %% [markdown]
# # Quiz 10
# แก้ code ของกราฟข้างบน ให้ boxplot แสดงในแนวนอน และ boxplot Lat อยู่ยน Long

# %%
plt.subplot(2, 1, 1) # 2 rows, 1 column, first plot
plt.boxplot(stopandsearch_df['Latitude'].dropna(), whis=1, vert=False, showmeans=True, meanline=True)
plt.title('Latitude Distribution')
plt.xlabel('Latitude')
plt.subplot(2, 1, 2) # 2 rows, 1 column, second plot
plt.boxplot(stopandsearch_df['Longitude'].dropna(), whis=1, vert=False, showmeans=True, meanline=True)
plt.title('Longitude Distribution')
plt.xlabel('Longitude')

plt.tight_layout() # Adjust layout to prevent titles/labels overlapping
plt.show()
